# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service as EdgeService
from webdriver_manager.microsoft import EdgeChromiumDriverManager
from selenium.webdriver.edge.options import Options as EdgeOptions

import datetime
import pandas as pd

# %%
# 设置 EdgeOptions
options = EdgeOptions()
options.add_argument("--headless")  # 无头模式
# 初始化 WebDriver
driver = webdriver.Edge(service=EdgeService(EdgeChromiumDriverManager().install()), options=options)

today = datetime.datetime.now().strftime("%m-%d")
yesterday = (datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%m-%d")
companies = pd.read_csv("data/sichuan.csv")

# %%
urls = companies["website"]
names =  companies["name"]
codes = companies["code"]

# %%
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

# %%
category_list = []

# 遍历每个URL进行抓取
for i in range(len(urls)):
    print(urls[i])
    driver.get(urls[i])

    try:
        div = driver.find_element(By.CSS_SELECTOR, "div.xgbk")
        content = div.get_attribute('outerHTML')
        
        soup = BeautifulSoup(content, 'html.parser')
        category = soup.find_all("a")
        # 提取文本
        text = category[0].get_text(strip=True)  # strip=True 去掉多余的空格或换行符
        print(text)
    except Exception as e:
        text = "未知"
    category_list.append(text)
# Out:
# https://quote.eastmoney.com/unify/r/0.002466
# 能源金属
# https://quote.eastmoney.com/unify/r/0.000598
# 公用事业
# https://quote.eastmoney.com/unify/r/1.601838
# 银行
# https://quote.eastmoney.com/unify/r/0.002312
# 化肥行业
# https://quote.eastmoney.com/unify/r/0.300841
# 生物制品
# https://quote.eastmoney.com/unify/r/1.600603
# 物流行业
# https://quote.eastmoney.com/unify/r/0.000876
# 农牧饲渔
# https://quote.eastmoney.com/unify/r/1.601208
# 塑料制品
# https://quote.eastmoney.com/unify/r/0.000568
# 酿酒行业
# https://quote.eastmoney.com/unify/r/0.000155
# 电力行业
# https://quote.eastmoney.com/unify/r/1.600039
# 工程建设
# https://quote.eastmoney.com/unify/r/0.000858
# 酿酒行业
# https://quote.eastmoney.com/unify/r/0.002697
# 商业百货
# https://quote.eastmoney.com/unify/r/1.688709
# 半导体
# https://quote.eastmoney.com/unify/r/0.000688
# 有色金属
# https://quote.eastmoney.com/unify/r/0.002497
# 化学制品
# https://quote.eastmoney.com/unify/r/0.301050
# 半导体
# https://quote.eastmoney.com/unify/r/1.600793
# 造纸印刷
# https://quote.eastmoney.com/unify/r/1.688302
# 生物制品
# https://quote.eastmoney.com/unify/r/1.688283
# 专用设备
# https://quote.eastmoney.com/unify/r/0.300425
# 环保行业
# https://quote.eastmoney.com/unify/r/1.603477
# 农牧饲渔
# https://quote.eastmoney.com/unify/r/1.688222
# 医疗服务
# https://quote.eastmoney.com/unify/r/1.600391
# 航天航空
# https://quote.eastmoney.com/unify/r/0.002539
# 化肥行业
# https://quote.eastmoney.com/unify/r/0.002749
# 农药兽药
# https://quote.eastmoney.com/unify/r/1.603053
# 燃气
# https://quote.eastmoney.com/unify/r/0.000593
# 燃气
# https://quote.eastmoney.com/unify/r/0.300937
# 医药商业
# https://quote.eastmoney.com/unify/r/0.301239
# 医疗服务
# https://quote.eastmoney.com/unify/r/0.002190
# 汽车零部件
# https://quote.eastmoney.com/unify/r/0.300987
# 文化传媒
# https://quote.eastmoney.com/unify/r/1.600331
# 有色金属
# https://quote.eastmoney.com/unify/r/0.300535
# 化学制品
# https://quote.eastmoney.com/unify/r/0.002951
# 互联网服务
# https://quote.eastmoney.com/unify/r/1.600353
# 电子元件
# https://quote.eastmoney.com/unify/r/0.002253
# 软件开发
# https://quote.eastmoney.com/unify/r/0.000628
# 工程建设
# https://quote.eastmoney.com/unify/r/1.603679
# 光学光电子
# https://quote.eastmoney.com/unify/r/0.002268
# 软件开发
# https://quote.eastmoney.com/unify/r/1.600644
# 电力行业
# https://quote.eastmoney.com/unify/r/1.603327
# 消费电子
# https://quote.eastmoney.com/unify/r/0.002246
# 化学制品
# https://quote.eastmoney.com/unify/r/1.688311
# 通信设备
# https://quote.eastmoney.com/unify/r/0.000629
# 钢铁行业
# https://quote.eastmoney.com/unify/r/0.002977
# 通信设备
# https://quote.eastmoney.com/unify/r/1.600839
# 家电行业
# https://quote.eastmoney.com/unify/r/0.301233
# 橡胶制品
# https://quote.eastmoney.com/unify/r/1.688629
# 电子元件
# https://quote.eastmoney.com/unify/r/1.688117
# 化学制药
# https://quote.eastmoney.com/unify/r/0.002023
# 航天航空
# https://quote.eastmoney.com/unify/r/1.688511
# 电子元件
# https://quote.eastmoney.com/unify/r/1.600979
# 电力行业
# https://quote.eastmoney.com/unify/r/1.688506
# 生物制品
# https://quote.eastmoney.com/unify/r/0.000888
# 旅游酒店
# https://quote.eastmoney.com/unify/r/0.002773
# 化学制药
# https://quote.eastmoney.com/unify/r/1.600674
# 电力行业
# https://quote.eastmoney.com/unify/r/1.600392
# 小金属
# https://quote.eastmoney.com/unify/r/0.000801
# 家电行业
# https://quote.eastmoney.com/unify/r/0.300696
# 航天航空
# https://quote.eastmoney.com/unify/r/1.600505
# 电力行业
# https://quote.eastmoney.com/unify/r/1.600702
# 酿酒行业
# https://quote.eastmoney.com/unify/r/1.600875
# 电源设备
# https://quote.eastmoney.com/unify/r/0.002422
# 化学制药
# https://quote.eastmoney.com/unify/r/0.300678
# 互联网服务
# https://quote.eastmoney.com/unify/r/0.300502
# 通信设备
# https://quote.eastmoney.com/unify/r/1.600101
# 电力行业
# https://quote.eastmoney.com/unify/r/1.600438
# 光伏设备

# %%
companies["category"] = category_list

# %%
companies.to_csv("data/sichuan_new.csv", index=False)

# %%
unique_categories = set(category_list)
# 将去重后的类别保存到txt文件
file_path = "data/categories.txt"  # 文件名

with open(file_path, "w", encoding="utf-8") as file:
    for category in unique_categories:
        file.write(category + "\n")

print(f"Unique categories have been saved to {file_path}")
# Out:
# Unique categories have been saved to data/categories.txt

# %%
# 读取 CSV 文件
file_path = "data/sichuan_new.csv"  # 替换为你的文件路径
df = pd.read_csv(file_path)

# 按 category 列分组
grouped = df.groupby("category")

# 遍历每个分组并保存为单独的文件
output_dir = "output_categories/"  # 输出目录
import os
os.makedirs(output_dir, exist_ok=True)  # 创建目录

for category, group in grouped:
    output_file = os.path.join(output_dir, f"{category}.csv")
    group.to_csv(output_file, index=False, encoding="utf-8")
    print(f"Saved {category} group to {output_file}")
# Out:
# Saved 专用设备 group to output_categories/专用设备.csv
# Saved 中药 group to output_categories/中药.csv
# Saved 互联网服务 group to output_categories/互联网服务.csv
# Saved 仪器仪表 group to output_categories/仪器仪表.csv
# Saved 光伏设备 group to output_categories/光伏设备.csv
# Saved 光学光电子 group to output_categories/光学光电子.csv
# Saved 公用事业 group to output_categories/公用事业.csv
# Saved 农牧饲渔 group to output_categories/农牧饲渔.csv
# Saved 农药兽药 group to output_categories/农药兽药.csv
# Saved 包装材料 group to output_categories/包装材料.csv
# Saved 化学制品 group to output_categories/化学制品.csv
# Saved 化学制药 group to output_categories/化学制药.csv
# Saved 化学原料 group to output_categories/化学原料.csv
# Saved 化肥行业 group to output_categories/化肥行业.csv
# Saved 医疗器械 group to output_categories/医疗器械.csv
# Saved 医疗服务 group to output_categories/医疗服务.csv
# Saved 医药商业 group to output_categories/医药商业.csv
# Saved 半导体 group to output_categories/半导体.csv
# Saved 商业百货 group to output_categories/商业百货.csv
# Saved 塑料制品 group to output_categories/塑料制品.csv
# Saved 家用轻工 group to output_categories/家用轻工.csv
# Saved 家电行业 group to output_categories/家电行业.csv
# Saved 小金属 group to output_categories/小金属.csv
# Saved 工程咨询服务 group to output_categories/工程咨询服务.csv
# Saved 工程建设 group to output_categories/工程建设.csv
# Saved 工程机械 group to output_categories/工程机械.csv
# Saved 教育 group to output_categories/教育.csv
# Saved 文化传媒 group to output_categories/文化传媒.csv
# Saved 旅游酒店 group to output_categories/旅游酒店.csv
# Saved 有色金属 group to output_categories/有色金属.csv
# Saved 未知 group to output_categories/未知.csv
# Saved 橡胶制品 group to output_categories/橡胶制品.csv
# Saved 水泥建材 group to output_categories/水泥建材.csv
# Saved 汽车服务 group to output_categories/汽车服务.csv
# Saved 汽车零部件 group to output_categories/汽车零部件.csv
# Saved 消费电子 group to output_categories/消费电子.csv
# Saved 游戏 group to output_categories/游戏.csv
# Saved 燃气 group to output_categories/燃气.csv
# Saved 物流行业 group to output_categories/物流行业.csv
# Saved 环保行业 group to output_categories/环保行业.csv
# Saved 生物制品 group to output_categories/生物制品.csv
# Saved 电力行业 group to output_categories/电力行业.csv
# Saved 电子元件 group to output_categories/电子元件.csv
# Saved 电源设备 group to output_categories/电源设备.csv
# Saved 电网设备 group to output_categories/电网设备.csv
# Saved 纺织服装 group to output_categories/纺织服装.csv
# Saved 综合行业 group to output_categories/综合行业.csv
# Saved 能源金属 group to output_categories/能源金属.csv
# Saved 航天航空 group to output_categories/航天航空.csv
# Saved 装修建材 group to output_categories/装修建材.csv
# Saved 证券 group to output_categories/证券.csv
# Saved 贵金属 group to output_categories/贵金属.csv
# Saved 软件开发 group to output_categories/软件开发.csv
# Saved 通信设备 group to output_categories/通信设备.csv
# Saved 通用设备 group to output_categories/通用设备.csv
# Saved 造纸印刷 group to output_categories/造纸印刷.csv
# Saved 酿酒行业 group to output_categories/酿酒行业.csv
# Saved 钢铁行业 group to output_categories/钢铁行业.csv
# Saved 铁路公路 group to output_categories/铁路公路.csv
# Saved 银行 group to output_categories/银行.csv
# Saved 食品饮料 group to output_categories/食品饮料.csv

# %%
# 创建一个新的 DataFrame，将每组数据依次添加，并用空行隔开
output_df = pd.DataFrame()

for category, group in grouped:
    output_df = pd.concat([output_df, group, pd.DataFrame([{}])])  # 添加空行

# 保存到新的 CSV 文件
output_file = "data/sichuan_grouped.csv"
output_df.to_csv(output_file, index=False, encoding="utf-8")

print(f"Grouped data saved to {output_file}")
# Out:
# Grouped data saved to data/sichuan_grouped.csv
